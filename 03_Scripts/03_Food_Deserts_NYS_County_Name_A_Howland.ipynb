# %% [markdown]
# # Prep NY State County data for JSON

# %% [markdown]
# ## This script contains the following points:
# 1. Import libraries
# 2. Import new_york.csv dataset and assign to ny1
# 3. Clean/verify dataset
# 4.Remove ' county' from 'County' column

# %% [markdown]
# ### 1. Importing Libraries

# %%
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# ### 2. Importing NY State dataset

# %%
path = r'C:\Users\howl6\OneDrive\Certificates\CareerFoundry\Coursework\Data_Immersion\Chapter 6\Food_Desert'

# %%
ny1 = pd.read_csv(os.path.join(path, '02_Data', 'cleaned_data', 'new_york.csv'), index_col=False)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### 3. Cleaning and verifying dataset

# %%
# print header
ny1.head()
# Out:
#    Unnamed: 0        Tract         County  Urban  Total_Population  \
# 0           0  36001000100  Albany County      1              2139
# 1           1  36001000200  Albany County      1              6046
# 2           2  36001000300  Albany County      1              5888
# 3           3  36001000401  Albany County      1              2227
# 4           4  36001000403  Albany County      1              4415
#
#    Housing_Units  High_Share_Group  Total_Group_Quarters  \
# 0            784                 0                  79.0
# 1           2514                 0                  84.0
# 2           2581                 0                 193.0
# 3           1017                 0                 575.0
# 4           2196                 0                  15.0
#
#    Percent_Group_Quarters  LILATracts_1And10  LILATracts_halfAnd10  \
# 0                    3.69                  1                     1
# 1                    1.39                  1                     1
# ...

# %%
# number of rows/columns
ny1.shape
# Out:
# (4870, 148)

# %%
ny1.columns
# Out:
# Index(['Unnamed: 0', 'Tract', 'County', 'Urban', 'Total_Population',
#        'Housing_Units', 'High_Share_Group', 'Total_Group_Quarters',
#        'Percent_Group_Quarters', 'LILATracts_1And10',
#        ...
#        'Total_White', 'Total_Black', 'Total_Asian', 'Total_NHOPI',
#        'Total_AIAN', 'Total_OMulti', 'Total_Hispanic', 'Total_No_Vehicle',
#        'Total_SNAP', 'Population_Size'],
#       dtype='object', length=148)

# %%
ny2 = ny1.drop(columns = ['Unnamed: 0'])

# %%
ny2.columns
# Out:
# Index(['Tract', 'County', 'Urban', 'Total_Population', 'Housing_Units',
#        'High_Share_Group', 'Total_Group_Quarters', 'Percent_Group_Quarters',
#        'LILATracts_1And10', 'LILATracts_halfAnd10',
#        ...
#        'Total_White', 'Total_Black', 'Total_Asian', 'Total_NHOPI',
#        'Total_AIAN', 'Total_OMulti', 'Total_Hispanic', 'Total_No_Vehicle',
#        'Total_SNAP', 'Population_Size'],
#       dtype='object', length=147)

# %%
ny2.head()
# Out:
#          Tract         County  Urban  Total_Population  Housing_Units  \
# 0  36001000100  Albany County      1              2139            784
# 1  36001000200  Albany County      1              6046           2514
# 2  36001000300  Albany County      1              5888           2581
# 3  36001000401  Albany County      1              2227           1017
# 4  36001000403  Albany County      1              4415           2196
#
#    High_Share_Group  Total_Group_Quarters  Percent_Group_Quarters  \
# 0                 0                  79.0                    3.69
# 1                 0                  84.0                    1.39
# 2                 0                 193.0                    3.28
# 3                 0                 575.0                   25.82
# 4                 0                  15.0                    0.34
#
#    LILATracts_1And10  LILATracts_halfAnd10  LILATracts_1And20  \
# 0                  1                     1                  1
# ...

# %% [markdown]
# ### 4. Remove ' county' from 'County' name

# %%
ny2['County'] = ny2['County'].apply(lambda x: x.replace(' County', ''))

# %%
ny2.head()
# Out:
#          Tract  County  Urban  Total_Population  Housing_Units  \
# 0  36001000100  Albany      1              2139            784
# 1  36001000200  Albany      1              6046           2514
# 2  36001000300  Albany      1              5888           2581
# 3  36001000401  Albany      1              2227           1017
# 4  36001000403  Albany      1              4415           2196
#
#    High_Share_Group  Total_Group_Quarters  Percent_Group_Quarters  \
# 0                 0                  79.0                    3.69
# 1                 0                  84.0                    1.39
# 2                 0                 193.0                    3.28
# 3                 0                 575.0                   25.82
# 4                 0                  15.0                    0.34
#
#    LILATracts_1And10  LILATracts_halfAnd10  LILATracts_1And20  \
# 0                  1                     1                  1
# ...

# %%
ny2.tail()
# Out:
#             Tract County  Urban  Total_Population  Housing_Units  \
# 4865  36123150100  Yates      0              5942           2200
# 4866  36123150200  Yates      0              5561           2138
# 4867  36123150300  Yates      0              5348           2074
# 4868  36123150400  Yates      0              3973           1369
# 4869  36123150500  Yates      0              4524           1736
#
#       High_Share_Group  Total_Group_Quarters  Percent_Group_Quarters  \
# 4865                 0                 134.0                    2.26
# 4866                 0                 287.0                    5.16
# 4867                 0                  38.0                    0.71
# 4868                 0                 828.0                   20.84
# 4869                 0                   0.0                    0.00
#
#       LILATracts_1And10  LILATracts_halfAnd10  LILATracts_1And20  \
# 4865                  0                     0                  0
# ...

# %%
# exporting NY State data with revised columns to CSV file
ny2.to_csv(os.path.join(path, '02_Data', 'cleaned_data', 'new_york2.csv'))
